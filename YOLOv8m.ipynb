# %%
! pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 10.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
! pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 23.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="XROkBOp3fXs8NJvfuSo3")
project = rf.workspace("innodatatics1").project("pipe-inventory")
dataset = project.version(5).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.134`, to intall it `pip install ultralytics==8.0.134`.
# ...
# Extracting Dataset Version Zip to pipe-inventory-5 in yolov8:: 100%|██████████| 3516/3516 [00:01<00:00, 3489.92it/s]

# %%
# %cd {HOME}
! yolo task = detect mode = predict model = yolov8m.pt conf = 0.25 source = /content/pipe-inventory-5/train/images/a-1-_jpg.rf.769040c18e41c8941b05e74f5911b098.jpg
# Out:
# /content
# ...
# 100% 49.7M/49.7M [00:00<00:00, 239MB/s]
# Ultralytics YOLOv8.0.199 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
#
# image 1/1 /content/pipe-inventory-5/train/images/a-1-_jpg.rf.769040c18e41c8941b05e74f5911b098.jpg: 640x640 1 giraffe, 47.8ms
# Speed: 1.8ms preprocess, 47.8ms inference, 35.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from PIL import Image

# %%
pip install Pillow

# %%
from IPython.display import display, Image

# %%
# %cd {HOME}
Image(filename='/content/pipe-inventory-5/train/images/a-1-_jpg.rf.769040c18e41c8941b05e74f5911b098.jpg', height=600)
# Out:
# /content

# %%
# %cd {HOME}
! yolo task = detect mode = train model = yolov8m.pt data= '/content/pipe-inventory-5/data.yaml'  epochs = 10 imgsz = 512
# Out:
# /content
# Ultralytics YOLOv8.0.199 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train2/
# Out:
# args.yaml					    labels.jpg	  train_batch0.jpg
# confusion_matrix_normalized.png			    P_curve.png   train_batch1.jpg
# confusion_matrix.png				    PR_curve.png  train_batch2.jpg
# events.out.tfevents.1697531681.79cedbe4456f.1800.0  R_curve.png   val_batch0_labels.jpg
# F1_curve.png					    results.csv   val_batch0_pred.jpg
# labels_correlogram.jpg				    results.png   weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/results.png', width=600)
# Out:
# /content

# %%
{HOME}
Image(filename=f'{HOME}/runs/detect/train2/val_batch0_pred.jpg', width=600)

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train2/weights/best.pt data=/content/pipe-inventory-5/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.0.199 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25853656 parameters, 0 gradients, 78.8 GFLOPs
# val: Scanning /content/pipe-inventory-5/valid/labels.cache... 51 images, 3 backgrounds, 0 corrupt: 100% 51/51 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:57<00:00, 14.31s/it]
#                    all         51      23393      0.711      0.391      0.488      0.323
#               C 32 2.5         51       1995      0.741      0.379       0.58      0.253
#               C 38 2.9         51       2259      0.877       0.52      0.706      0.346
#            R 20 40 1.9         51        582          0          0          0          0
#            R 25 75 1.9         51       1389      0.941      0.189      0.551      0.317
#            R 48 96 2.0         51        108      0.277       0.13     0.0426     0.0377
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/content/pipe-inventory-5/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.0.199 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25853656 parameters, 0 gradients, 78.8 GFLOPs
#
# image 1/42 /content/pipe-inventory-5/test/images/a-17-_jpg.rf.0a28e64c787865757dd57c500aed8f42.jpg: 512x512 48 R 25 75 1.9s, 1 S 20 20 1.2, 146 S 50 50 1.5s, 105 S 72 72 4.0s, 25.5ms
# image 2/42 /content/pipe-inventory-5/test/images/a-34-_jpg.rf.4af9df7de21c844fcf686c1410c054d1.jpg: 512x512 35 R 25 75 1.9s, 4 S 20 20 1.2s, 152 S 50 50 1.5s, 109 S 72 72 4.0s, 25.6ms
# image 3/42 /content/pipe-inventory-5/test/images/a-41-_jpg.rf.a5a29bfa22f4adea42b0f474e14d14a6.jpg: 512x512 33 R 25 75 1.9s, 1 S 20 20 1.2, 160 S 50 50 1.5s, 106 S 72 72 4.0s, 25.5ms
# image 4/42 /content/pipe-inventory-5/test/images/a-50-_jpg.rf.e02d6fb3ec6dc01f8d4acc860cae8edf.jpg: 512x512 30 R 25 75 1.9s, 163 S 50 50 1.5s, 107 S 72 72 4.0s, 25.4ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/content/runs/detect/predict2/a-50-_jpg.rf.e02d6fb3ec6dc01f8d4acc860cae8edf.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
